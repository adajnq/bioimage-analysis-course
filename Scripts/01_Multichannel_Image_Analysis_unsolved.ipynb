# %% [markdown]
# # 🔬 Multichannel 3D Microscopy: Channel Splitting & Biological Analysis
# In this notebook, you'll explore a real 3D fluorescence microscopy dataset and learn how to split and analyze channels to distinguish biological structures like **nuclei** and **cell membranes**.

# %% [markdown]
# ## 1. 📦 Imports and Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.data import cells3d
# %matplotlib inline

# %% [markdown]
# ## 2. 📥 Load the `cells3d()` dataset
# Discover this data
# First, begin by examining what each of the dimensions mean

# %%
# Load image
cells = cells3d()
shape = 
print(f"Shape: {shape}")
# Out:
# Shape: (60, 2, 256, 256)

# %% [markdown]
# ## 3. 🧪 Split Channels
# Save each of the images in a separate variable for doing some analysis

# %%
# Extract membrane and nuclei channels
membranes = 
nuclei = 
print(f"Membranes shape: {membranes.shape}")
print(f"Nuclei shape: {nuclei.shape}")
# Out:
# Membranes shape: (60, 256, 256)
# Nuclei shape: (60, 256, 256)

# %% [markdown]
# ## 4. 🖼️ Visualize a Middle Slice from Each Channel

# %%
#Slice the membrane channel

#Slice the nuclei channel

fig, ax = plt.subplots(1, 2, figsize=(10, 5))

ax[0].imshow()#complete with membrane channel
ax[0].set_title('Membranes - Middle Z')

ax[1].imshow()#complete with nuclei channel
ax[1].set_title('Nuclei - Middle Z')
for a in ax:
    a.axis('off')
plt.show()

# %% [markdown]
# ## 5. 🔍 Questions for You
# **Think and discuss:**
# 1. What are the differences in appearance between the two channels?
# 2. Which structures are highlighted in each channel?
# 3. Why might we want to analyze each channel separately?

# %% [markdown]
# ## 6. 🧭 BONUS: Explore the Full Stack in Napari
# **Napari** is a powerful tool to explore 3D image stacks interactively.

# %%
import napari
viewer = napari.Viewer()
#Add nuclei to the viewer

#Add membranes to the viewer

#Run napari
napari.run()

# %% [markdown]
# # 7. Segmentation

# %%
from stardist.models import StarDist2D
from stardist.data import test_image_nuclei_2d
from stardist.plot import render_label
from csbdeep.utils import normalize

# prints a list of available models
StarDist2D.from_pretrained()
# creates a pretrained model
model = StarDist2D.from_pretrained('2D_versatile_fluo')


#Use model.predict_instances() to generate a mask over your image (you can add the z score you prefer)

# Display image and mask overlay

# %% [markdown]
# <!-- # 7. Segmentation -->
